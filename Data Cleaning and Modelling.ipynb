# %%
import pandas as pd
import eli5
import re
import numpy as np
import sklearn
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.pipeline import FeatureUnion
from sklearn.pipeline import Pipeline, make_pipeline
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.metrics import classification_report
from sklearn.grid_search import GridSearchCV
from sklearn.feature_extraction import DictVectorizer
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn import model_selection
from sklearn.metrics import confusion_matrix, precision_score, precision_recall_curve, recall_score, f1_score

# %% [markdown]
# # 1. Import and clean the dataset

# %%
#import dataset, remove the 'no match' rows
song_data = pd.read_csv("subsongdata_57650.csv")
song_data = song_data[['artist','song','text','explicit_label']]
song_data = song_data.loc[song_data['explicit_label'] != 'no match']
#remove'\n' from the lyrics
re_drop = re.compile(r'\n')        
song_data[['text']] = song_data[['text']].applymap(lambda x:re_drop.sub(' ',x))

song_data
# Out:
#                artist                                             song  \
# 1                ABBA                                 Andante, Andante
# 2                ABBA                                   As Good As New
# 4                ABBA                                 Bang-A-Boomerang
# 7                ABBA                                       Chiquitita
# 11               ABBA                                    Dancing Queen
# 12               ABBA                                      Disillusion
# 13               ABBA                            Does Your Mother Know
# 15               ABBA                                   Dum Dum Diddle
# 18               ABBA                                         Fernando
# 21               ABBA         From A Twinkling Star To A Passing Angel
# 22               ABBA                                Gimme Gimme Gimme
# 24               ABBA                       Gonna Sing You My Lovesong
# 26               ABBA                                     Happy Hawaii
# 27               ABBA                                   Happy New Year
# 28               ABBA                               He Is Your Brother
# 31               ABBA                                    Hey Hey Helen
# 32               ABBA                                Hole In Your Soul
# 33               ABBA                                     Honey, Honey
# 34               ABBA                                 I Am Just A Girl
# 35               ABBA                                    I Am The City
# 36               ABBA                     I Do, I Do, I Do, I Do, I Do
# 37               ABBA                                   I Have A Dream
# 38               ABBA                            I Let The Music Speak
# 39               ABBA                           I Saw It In The Mirror
# 40               ABBA                             I Wonder (Departure)
# 41               ABBA                      I Wonder (Departure) [Live]
# 42               ABBA                      If It Wasn't For The Nights
# 43               ABBA                                 I'm A Marionette
# 44               ABBA                        I've Been Waiting For You
# 47               ABBA                                   King Kong Song
# ...               ...                                              ...
# 57541            Z-Ro                          Don't Wanna Hurt Nobody
# 57543            Z-Ro                                 Gonna Get Easier
# 57544            Z-Ro                                   Gripping Grain
# 57545            Z-Ro                              Guerilla Till I Die
# 57550            Z-Ro                                 Lord Tell Me Why
# 57560            Z-Ro                               Talkin' Down On Me
# 57561            Z-Ro                                  That'z Who I Am
# 57565  Zac Brown Band                           Different Kind Of Fine
# 57566  Zac Brown Band                                  I Play The Road
# 57567  Zac Brown Band                                           Jolene
# 57568  Zac Brown Band                                  Keep Me In Mind
# 57569  Zac Brown Band                               Last But Not Least
# 57571  Zac Brown Band                                    Make this day
# 57572  Zac Brown Band                             Sic 'Em On A Chicken
# 57578      Zakk Wylde                                I Thank You Child
# 57580      Zakk Wylde                                     Sold My Soul
# 57582      Zakk Wylde                                The Things You Do
# 57583      Zakk Wylde                                  Too Numb To Cry
# 57584      Zakk Wylde                                 Way Beyond Empty
# 57586             Zao                                    5 Year Winter
# 57587             Zao                                  All Else Failed
# 57588             Zao                               In Loving Kindness
# 57589             Zao               Lies Of Serpents, A River Of Tears
# 57590             Zao                                  Parade Of Chaos
# 57592             Zao                              Times Of Separation
# 57593             Zao  To Think Of You Is To Treasure An Absent Memory
# 57605           Zebra                                 As I Said Before
# 57608           Zebra                          Hard Living Without You
# 57609           Zebra                               When You Get There
# 57612           Zebra                    You're Only Losing Your Heart
#
#                                                     text explicit_label
# 1      Take it easy with me, please   Touch me gently...          False
# 2      I'll never know why I had to go   Why I had to...          False
# 4      Making somebody happy is a question of give an...          False
# 7      Chiquitita, tell me what's wrong   You're ench...          False
# 11     You can dance, you can jive, having the time o...          False
# 12     Changing, moving in a circle   I can see your ...          False
# 13     You're so hot, teasing me   So you're blue but...          False
# 15     I can hear how you work, practising hard   Pla...          False
# 18     Can you hear the drums Fernando?   I remember ...          False
# 21     Twinkle, Twinkle little star   How I wonder wh...          False
# 22     Half past twelve   And I'm watching the late s...          False
# 24     You say she's been mad at you   Then you say y...          False
# 26     Agnetha, Frida Early this morning I drove in t...          False
# 27     No more champagne   And the fireworks are thro...          False
# 28     Benny I was a fighter, always looking for trou...          False
# 31     So at last you're free   It's the way you want...          False
# 32     You feel bad, let me tell you, we all get the ...          False
# 33     Honey honey, how you thrills me, ah-hah, honey...          False
# 34     I am just a girl   One among the others, nothi...          False
# 35     i am the city, you let me be   i am the city  ...          False
# 36     Love me or leave me   Make your choice but bel...          False
# 37     I have a dream, a song to sing   To help me co...          False
# 38     I'm hearing images, I'm seeing songs   No poet...          False
# 39     I saw it in the mirror   I saw it in my face  ...          False
# 40     This park and these houses, old streets I have...          False
# 41     This park and these houses   Old streets I hav...          False
# 42     I got appointments, work I have to do   Keepin...          False
# 43     You're so free   That's what everybody's telli...          False
# 44     I, I've been in love before   I thought I woul...          False
# 47     Well I was looking at a movie on the TV last n...          False
# ...                                                  ...            ...
# 57541  You already know who it is nigga, 'King of Da ...           True
# 57543  (talking)   This that boy Sinner Tone, better ...           True
# 57544  What, is this bitch fucking with Z-Ro   Mother...           True
# 57545  [Hook - 2x]   Guerilla till I die, mama don't ...           True
# 57550  (Chorus - 2x)   Lord tell me why   Ooh child, ...           True
# 57560  [Z-Ro]   Since I been out by myself, I keep th...           True
# 57561  [Z-Ro]   Houston Texas is my city, Ridgemont 4...           True
# 57565  She make a train take a dirt road   Make it st...          False
# 57566  I play the road,   And the highway is our song...          False
# 57567  Cocaine flame in my bloodstream   Sold my coat...          False
# 57568  1, 2, 3   This is gonna be funky      How come...          False
# 57569  There ain't enough of me to go around   Got al...          False
# 57571  Got a quarter...   I passed out last night and...          False
# 57572  [Chorus]   Sic 'em on a chicken.   Sic 'em on ...          False
# 57578  All for you   Everlasting love forever skies o...          False
# 57580  Without you woman by my side,   I'm contemplat...          False
# 57582  Colour my world all black and blue   The hell ...          False
# 57583  I see you across the room   Search for some ha...          False
# 57584  If I could I surely would   Child ease your pa...          False
# 57586  Dear Tiffany,   You've mad me nauseous for the...          False
# 57587  (A throne in Heaven sat empty for 33 years.) W...          False
# 57588  We are a new creation, the old has gone, the n...          False
# 57589  Your eyes   Your eyes   Your eyes search for m...          False
# 57590  We march like fools in the parade of chaos.   ...          False
# 57592  Once again to strive, to beat it out   Over an...          False
# 57593  When you shut your eyes and fell asleep   Dark...          False
# 57605  And I said before   I don't want no more   And...          False
# 57608  Nothing to say no place to hide   I can't find...          False
# 57609  You wake up in the morning   And you're not fe...          False
# 57612  Don't' do anything I wouldn't do   Pass me any...          False
#
# [24676 rows x 4 columns]

# %% [markdown]
# # 2. Split into training dataset and test dataset

# %%
#extract all the rows with explicit_label = True
song_data_1 = song_data.loc[song_data['explicit_label'] == 'True']
#song_data_1

#ramdomly extract 4068 rows with explicit_label = False, which is 3 times as many as song_data_1
song_data_0 = song_data.loc[song_data['explicit_label'] == 'False']
song_data_0 = song_data_0.sample(n=4068, replace=False, random_state=100)
#song_data_0

#ramdomly extract 1356 data as test set, leaving 4068 as training data
x = song_data_0[['artist','song','text']].append(song_data_1[['artist','song','text']])
y = song_data_0[['explicit_label']].append(song_data_1[['explicit_label']])
x_train, x_test, y_train, y_test = sklearn.model_selection.train_test_split(x, y, test_size=1356, random_state=100)
#y_train.loc[y_train['explicit_label']=='True']

# %%
train_label = []
for i in range(len(y_train)):
    l = y_train.iloc[i,0]
    if l=="False":
        l = 0
    else:
        l = 1
    train_label.append(l)

test_label = []
for i in range(len(y_test)):
    l = y_test.iloc[i,0]
    if l=="False":
        l = 0
    else:
        l = 1
    test_label.append(l)
    
train_data = []
for i in range(len(x_train)):
    text = x_train.iloc[i,2]
    train_data.append(text)
    
test_data = []
for i in range(len(x_test)):
    text = x_test.iloc[i,2]
    test_data.append(text)

# %% [markdown]
# # 4. Customized features

# %% [markdown]
# ## Import bad words list

# %%
file = open('abbo.txt','r')
file = list(file)
bad_words = []
for w in file:
    bad_words.append(re.sub(r'\n','',w))

# %% [markdown]
# ## Create customized features

# %%
class CustomFeats(BaseEstimator, TransformerMixin):
    def __init__(self):
      self.feat_names = set()

    def fit(self, x, y=None):
        return self

    @staticmethod
    def features(review):
      return {
          'num_word': get_num_words(review),
          'bad_word': get_bad_words(review),
          'lda_word': get_lda_words(review)
      }

    def get_feature_names(self):
        return list(self.feat_names)
      
    def transform(self, reviews):
      feats = []
      for review in reviews:
        f = self.features(review)
        [self.feat_names.add(k) for k in f] 
        feats.append(f)
      return feats

#feats = make_pipeline(CustomFeats(), DictVectorizer())
feats = FeatureUnion([
     ('custom', make_pipeline(CustomFeats(), DictVectorizer())),
     ('bag_of_words', TfidfVectorizer(stop_words='english'))
 ])

# %%
def get_bad_words(review):
  target_word = bad_words
  count = 0
  threshold = 0
  for t in target_word:
        if review.find(t) != -1:
            count += 1
  return count > threshold

def get_num_words(review):
  threshold = 0
  words = review.split(' ')
  count = len(list(words))
  return count > threshold

def get_lda_words(review):
  target_word = ['chorus','girl','money','baby','nigga','bitch','want','love','wanna','gonna','come','right','shit','feel']
  count = 0
  threshold = 0
  for t in target_word:
        if review.find(t) != -1:
            count += 1
  return count > threshold

# %% [markdown]
# # 5. Modelling

# %%
def classification(feats, model):  
  train_vecs = feats.fit_transform(train_data)
  test_vecs = feats.transform(test_data)
    
  model.fit(train_vecs, train_label)

  train_preds = model.predict(train_vecs)
  train_f1 = f1_score(train_label, train_preds, average='micro')

  test_preds = model.predict(test_vecs)
  test_f1 = f1_score(test_label, test_preds, average='micro')

  cm = confusion_matrix(test_label, test_preds)
  print("Confusion Matrix : \n", cm, " \n")

  report = classification_report(test_label, test_preds)
  print(report)

  return train_f1,test_f1

# %% [markdown]
# ## Parameters tunning with grid search

# %%
train_vecs = feats.fit_transform(train_data)
test_vecs = feats.transform(test_data)
param_test = {'max_depth':list(range(60,80,1))} #
gsearch = GridSearchCV(estimator = DecisionTreeClassifier(),
                       param_grid = param_test, scoring='recall', iid=False, cv=5)
gsearch.fit(train_vecs, train_label)
gsearch.grid_scores_, gsearch.best_params_, gsearch.best_score_
# Out:
# ([mean: 0.75898, std: 0.02110, params: {'max_depth': 60},
#   mean: 0.75510, std: 0.03388, params: {'max_depth': 61},
#   mean: 0.75413, std: 0.02093, params: {'max_depth': 62},
#   mean: 0.74733, std: 0.02037, params: {'max_depth': 63},
#   mean: 0.74442, std: 0.01816, params: {'max_depth': 64},
#   mean: 0.75219, std: 0.02236, params: {'max_depth': 65},
#   mean: 0.74150, std: 0.01547, params: {'max_depth': 66},
#   mean: 0.74440, std: 0.02797, params: {'max_depth': 67},
#   mean: 0.74830, std: 0.02964, params: {'max_depth': 68},
#   mean: 0.74345, std: 0.02489, params: {'max_depth': 69},
#   mean: 0.75508, std: 0.02938, params: {'max_depth': 70},
#   mean: 0.73859, std: 0.03331, params: {'max_depth': 71},
#   mean: 0.75119, std: 0.02418, params: {'max_depth': 72},
#   mean: 0.74926, std: 0.02127, params: {'max_depth': 73},
#   mean: 0.75023, std: 0.02864, params: {'max_depth': 74},
#   mean: 0.75508, std: 0.02027, params: {'max_depth': 75},
#   mean: 0.74828, std: 0.02634, params: {'max_depth': 76},
#   mean: 0.74248, std: 0.01248, params: {'max_depth': 77},
#   mean: 0.74926, std: 0.02398, params: {'max_depth': 78},
#   mean: 0.74538, std: 0.02319, params: {'max_depth': 79}],
#  {'max_depth': 60},
#  0.7589770305470045)

# %% [markdown]
# ## Logistic Regression

# %%
model_lo= LogisticRegression(C=50)
classification(feats, model_lo)
# Out:
# Confusion Matrix :
#  [[999  30]
#  [119 208]]
#
#              precision    recall  f1-score   support
#
#           0       0.89      0.97      0.93      1029
#           1       0.87      0.64      0.74       327
#
# avg / total       0.89      0.89      0.88      1356
# (0.9997541789577188, 0.890117994100295)

# %% [markdown]
# ## Random Forest

# %%
model_rf = RandomForestClassifier(n_estimators=110, max_depth=140, min_samples_split=30)
classification(feats, model_rf)
# Out:
# Confusion Matrix :
#  [[1011   18]
#  [ 118  209]]
#
#              precision    recall  f1-score   support
#
#           0       0.90      0.98      0.94      1029
#           1       0.92      0.64      0.75       327
#
# avg / total       0.90      0.90      0.89      1356
# (0.987708947885939, 0.8997050147492626)

# %% [markdown]
# ## KNN

# %%
model_knn= KNeighborsClassifier(n_neighbors=10) 
classification(feats, model_knn)
# Out:
# Confusion Matrix :
#  [[1014   15]
#  [ 206  121]]
#
#              precision    recall  f1-score   support
#
#           0       0.83      0.99      0.90      1029
#           1       0.89      0.37      0.52       327
#
# avg / total       0.85      0.84      0.81      1356
# (0.8502949852507374, 0.8370206489675516)

# %% [markdown]
# ## Decision Tree

# %%
model_dt = DecisionTreeClassifier(min_samples_split=0.4, max_depth=77)
classification(feats, model_dt)
# Out:
# Confusion Matrix :
#  [[944  85]
#  [ 57 270]]
#
#              precision    recall  f1-score   support
#
#           0       0.94      0.92      0.93      1029
#           1       0.76      0.83      0.79       327
#
# avg / total       0.90      0.90      0.90      1356
# (0.9434611602753196, 0.8952802359882006)

# %% [markdown]
# ## SVM

# %%
model_svm = SVC(C = 10000, kernel = 'rbf')
classification(feats, model_svm)
# Out:
# Confusion Matrix :
#  [[1012   17]
#  [ 142  185]]
#
#              precision    recall  f1-score   support
#
#           0       0.88      0.98      0.93      1029
#           1       0.92      0.57      0.70       327
#
# avg / total       0.89      0.88      0.87      1356
# (0.9397738446411013, 0.8827433628318584)
